# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
sig = gpd.read_file('./data/sig_20230729/sig.shp', encoding='cp949')
sig.head()
# Out:
#   SIG_CD    SIG_ENG_NM SIG_KOR_NM  \
# 0  11110     Jongno-gu        종로구
# 1  11140       Jung-gu         중구
# 2  11170    Yongsan-gu        용산구
# 3  11200  Seongdong-gu        성동구
# 4  11215   Gwangjin-gu        광진구
#
#                                             geometry
# 0  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2  POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3  POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4  POLYGON ((964825.058 1952633.250, 964875.565 1...

# %%
sig.plot()
# Out:
# <Axes: >

# %%
seoul = sig[sig['SIG_CD'].str.startswith('11')]

# %%
seoul.plot()
# Out:
# <Axes: >

# %%
plant_dot = gpd.read_file('./data/202211_생태계정밀조사_식물상_점/tbl_big_ecpe_flr_point.shp', encoding='utf-8')
plant_dot.head()
# Out:
#               SPCE_ID EXAMIN_REA SPCS_LCNM               SPCS_SCNCE  \
# 0  003000000000046616        식물상      민둥갈퀴            Galium kinuta
# 1  003000000000046108        식물상       연복초      Adoxa moschatellina
# 2  003000000000046111        식물상     청비녀골풀        Juncus papillosus
# 3  003000000000046118        식물상      고사리삼      Botrychium ternatum
# 4  003000000000046119        식물상      좀고사리  Pleurosoriopsis makinoi
#
#   EXAMIN_YEA  EXAMIN_BEG  EXAMIN_END INDVD_CO                       geometry
# 0       2015  2015-05-12  2015-05-12       15  POINT (292705.237 480856.256)
# 1       2015  2015-03-26  2015-03-26      150  POINT (299663.033 479455.049)
# 2       2015  2015-03-26  2015-03-26        5  POINT (299608.297 479266.330)
# 3       2015  2015-03-27  2015-03-27        3  POINT (310583.390 469266.978)
# 4       2015  2015-03-27  2015-03-27       25  POINT (309333.628 469290.951)

# %%
plant_dot.plot()
# Out:
# <Axes: >

# %%
ax = sig.plot(color='white', edgecolor='black', figsize=(10,10))
plant_dot.plot(ax=ax, color='red', markersize=1)
# Out:
# <Axes: >

# %%
# print('sig: ', sig.crs, '\nplant_dot: ', plant_dot.crs)
# type(sig.crs)
# sig = gpd.read_file('./data/sig_20230729/sig.shp', encoding='cp949')
# sig.crs
# seoul.crs
# plant_dot.crs

# %%
sig.crs

# %%
sig.head()
# Out:
#   SIG_CD    SIG_ENG_NM       SIG_KOR_NM  \
# 0  11110     Jongno-gu  b'c1beb7ceb1b8'
# 1  11140       Jung-gu      b'c1dfb1b8'
# 2  11170    Yongsan-gu  b'bfebbbeab1b8'
# 3  11200  Seongdong-gu  b'bcbab5bfb1b8'
# 4  11215   Gwangjin-gu  b'b1a4c1f8b1b8'
#
#                                             geometry
# 0  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2  POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3  POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4  POLYGON ((964825.058 1952633.250, 964875.565 1...

# %%
# sig.crs = "EPSG:4737"
# plant_dot.crs = "EPSG:4737"

# %%
sig_crs = sig.to_crs(epsg=4737)
plant_dot_crs = plant_dot.to_crs(epsg=4737)

# %%
ax = sig_crs.plot(color='white', edgecolor='black', figsize=(10,10))
plant_dot_crs.plot(ax=ax, color='navy', figsize=(10, 10))
# Out:
# <Axes: >
